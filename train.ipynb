# %%
# ======================================
# AGE & GENDER PREDICTION - UTKFACE DATASET
# ======================================

import os
import cv2
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# ==============================
# CONFIGURATION
# ==============================
DATASET_PATH = r"E:\ml project\UTKFace"  # change this to your folder path
IMG_SIZE = 128

# ==============================
# DATA LOADING (paths only)
# ==============================
def load_utkface_dataset(dataset_path):
    """Return lists of file paths, ages and genders without loading images into memory."""
    file_paths, ages, genders = [], [], []
    for filename in os.listdir(dataset_path):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            try:
                parts = filename.split("_")
                age = int(parts[0])
                gender = int(parts[1])  # 0 = male, 1 = female
                img_path = os.path.join(dataset_path, filename)
                file_paths.append(img_path)
                ages.append(age)
                genders.append(gender)
            except Exception:
                continue
    return file_paths, np.array(ages, dtype=np.int32), np.array(genders, dtype=np.int32)

print("Loading dataset (paths only)...")
file_paths, age_labels, gender_labels = load_utkface_dataset(DATASET_PATH)
print("✅ Dataset paths loaded")
print(f"Total Images: {len(file_paths)}")

# ==============================
# SPLIT PATHS (labels stay in memory but are small)
# ==============================
paths_train, paths_test, y_age_train, y_age_test, y_gender_train, y_gender_test = train_test_split(
    file_paths, age_labels, gender_labels, test_size=0.2, random_state=42
)

# Create tf.data datasets that load images on the fly to avoid large memory usage
AUTOTUNE = tf.data.AUTOTUNE

def _parse_function(path, age, gender):
    # path: tf.string scalar
    image_contents = tf.io.read_file(path)
    image = tf.io.decode_image(image_contents, channels=3, expand_animations=False)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.float32) / 255.0
    age = tf.cast(age, tf.float32)
    gender = tf.cast(gender, tf.float32)
    return image, {"age_output": age, "gender_output": gender}

batch_size = 64

train_ds = tf.data.Dataset.from_tensor_slices((paths_train, y_age_train, y_gender_train))
train_ds = train_ds.shuffle(buffer_size=1000)
train_ds = train_ds.map(lambda p,a,g: _parse_function(p,a,g), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(batch_size).prefetch(AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((paths_test, y_age_test, y_gender_test))
# No shuffle for test
test_ds = test_ds.map(lambda p,a,g: _parse_function(p,a,g), num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(batch_size).prefetch(AUTOTUNE)

# ==============================
# MODEL ARCHITECTURE
# ==============================
inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

x = Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
x = MaxPooling2D((2,2))(x)
x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
x = MaxPooling2D((2,2))(x)
x = Conv2D(128, (3,3), activation='relu', padding='same')(x)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dropout(0.5)(x)

# Output layers
age_output = Dense(1, activation='linear', name='age_output')(x)
gender_output = Dense(1, activation='sigmoid', name='gender_output')(x)

model = Model(inputs=inputs, outputs=[age_output, gender_output])

# ==============================
# COMPILE MODEL
# ==============================
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss={'age_output': 'mae', 'gender_output': 'binary_crossentropy'},
    metrics={'age_output': 'mae', 'gender_output': 'accuracy'}
)

model.summary()

# ==============================
# TRAIN MODEL
# ==============================
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=15,
    # If your dataset has fewer examples than batch_size, you may need to set steps_per_epoch
)

# ==============================
# SAVE MODEL
# ==============================
model.save("age_gender_model.h5")
print("✅ Model saved as age_gender_model.h5")
# Out:
# Loading dataset (paths only)...
# ✅ Dataset paths loaded
# Total Images: 23708
# ✅ Dataset paths loaded
# Total Images: 23708
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 32768)     │          0 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 32768)     │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │     32,769 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │     32,769 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 158,786 (620.26 KB)
#  Trainable params: 158,786 (620.26 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 288s 960ms/step - age_output_loss: 15.4750 - age_output_mae: 15.4791 - gender_output_accuracy: 0.6733 - gender_output_loss: 0.6144 - loss: 16.0937 - val_age_output_loss: 14.1945 - val_age_output_mae: 14.1685 - val_gender_output_accuracy: 0.7741 - val_gender_output_loss: 0.4752 - val_loss: 14.6461
# Epoch 2/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 288s 960ms/step - age_output_loss: 15.4750 - age_output_mae: 15.4791 - gender_output_accuracy: 0.6733 - gender_output_loss: 0.6144 - loss: 16.0937 - val_age_output_loss: 14.1945 - val_age_output_mae: 14.1685 - val_gender_output_accuracy: 0.7741 - val_gender_output_loss: 0.4752 - val_loss: 14.6461
# Epoch 2/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 280s 941ms/step - age_output_loss: 12.5150 - age_output_mae: 12.5191 - gender_output_accuracy: 0.7654 - gender_output_loss: 0.5338 - loss: 13.0532 - val_age_output_loss: 10.9878 - val_age_output_mae: 11.0013 - val_gender_output_accuracy: 0.8288 - val_gender_output_loss: 0.3835 - val_loss: 11.3872
# Epoch 3/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 280s 941ms/step - age_output_loss: 12.5150 - age_output_mae: 12.5191 - gender_output_accuracy: 0.7654 - gender_output_loss: 0.5338 - loss: 13.0532 - val_age_output_loss: 10.9878 - val_age_output_mae: 11.0013 - val_gender_output_accuracy: 0.8288 - val_gender_output_loss: 0.3835 - val_loss: 11.3872
# Epoch 3/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 270s 908ms/step - age_output_loss: 11.0173 - age_output_mae: 11.0169 - gender_output_accuracy: 0.8092 - gender_output_loss: 0.4487 - loss: 11.4653 - val_age_output_loss: 10.4470 - val_age_output_mae: 10.4603 - val_gender_output_accuracy: 0.8412 - val_gender_output_loss: 0.3556 - val_loss: 10.8180
# Epoch 4/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 270s 908ms/step - age_output_loss: 11.0173 - age_output_mae: 11.0169 - gender_output_accuracy: 0.8092 - gender_output_loss: 0.4487 - loss: 11.4653 - val_age_output_loss: 10.4470 - val_age_output_mae: 10.4603 - val_gender_output_accuracy: 0.8412 - val_gender_output_loss: 0.3556 - val_loss: 10.8180
# Epoch 4/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 281s 946ms/step - age_output_loss: 10.2612 - age_output_mae: 10.2641 - gender_output_accuracy: 0.8323 - gender_output_loss: 0.3964 - loss: 10.6605 - val_age_output_loss: 9.8012 - val_age_output_mae: 9.8212 - val_gender_output_accuracy: 0.8549 - val_gender_output_loss: 0.3298 - val_loss: 10.1524
# Epoch 5/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 281s 946ms/step - age_output_loss: 10.2612 - age_output_mae: 10.2641 - gender_output_accuracy: 0.8323 - gender_output_loss: 0.3964 - loss: 10.6605 - val_age_output_loss: 9.8012 - val_age_output_mae: 9.8212 - val_gender_output_accuracy: 0.8549 - val_gender_output_loss: 0.3298 - val_loss: 10.1524
# Epoch 5/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 277s 930ms/step - age_output_loss: 9.6729 - age_output_mae: 9.6760 - gender_output_accuracy: 0.8437 - gender_output_loss: 0.3733 - loss: 10.0493 - val_age_output_loss: 9.2362 - val_age_output_mae: 9.2469 - val_gender_output_accuracy: 0.8589 - val_gender_output_loss: 0.3352 - val_loss: 9.5831
# Epoch 6/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 277s 930ms/step - age_output_loss: 9.6729 - age_output_mae: 9.6760 - gender_output_accuracy: 0.8437 - gender_output_loss: 0.3733 - loss: 10.0493 - val_age_output_loss: 9.2362 - val_age_output_mae: 9.2469 - val_gender_output_accuracy: 0.8589 - val_gender_output_loss: 0.3352 - val_loss: 9.5831
# Epoch 6/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 289s 974ms/step - age_output_loss: 9.1766 - age_output_mae: 9.1689 - gender_output_accuracy: 0.8567 - gender_output_loss: 0.3508 - loss: 9.5199 - val_age_output_loss: 8.7662 - val_age_output_mae: 8.7837 - val_gender_output_accuracy: 0.8623 - val_gender_output_loss: 0.3123 - val_loss: 9.0985
# Epoch 7/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 289s 974ms/step - age_output_loss: 9.1766 - age_output_mae: 9.1689 - gender_output_accuracy: 0.8567 - gender_output_loss: 0.3508 - loss: 9.5199 - val_age_output_loss: 8.7662 - val_age_output_mae: 8.7837 - val_gender_output_accuracy: 0.8623 - val_gender_output_loss: 0.3123 - val_loss: 9.0985
# Epoch 7/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 280s 943ms/step - age_output_loss: 8.9375 - age_output_mae: 8.9394 - gender_output_accuracy: 0.8636 - gender_output_loss: 0.3279 - loss: 9.2676 - val_age_output_loss: 9.3008 - val_age_output_mae: 9.3080 - val_gender_output_accuracy: 0.8752 - val_gender_output_loss: 0.2926 - val_loss: 9.6025
# Epoch 8/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 280s 943ms/step - age_output_loss: 8.9375 - age_output_mae: 8.9394 - gender_output_accuracy: 0.8636 - gender_output_loss: 0.3279 - loss: 9.2676 - val_age_output_loss: 9.3008 - val_age_output_mae: 9.3080 - val_gender_output_accuracy: 0.8752 - val_gender_output_loss: 0.2926 - val_loss: 9.6025
# Epoch 8/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 237s 799ms/step - age_output_loss: 8.6639 - age_output_mae: 8.6628 - gender_output_accuracy: 0.8717 - gender_output_loss: 0.3148 - loss: 8.9775 - val_age_output_loss: 8.2354 - val_age_output_mae: 8.2429 - val_gender_output_accuracy: 0.8790 - val_gender_output_loss: 0.2796 - val_loss: 8.5236
# Epoch 9/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 237s 799ms/step - age_output_loss: 8.6639 - age_output_mae: 8.6628 - gender_output_accuracy: 0.8717 - gender_output_loss: 0.3148 - loss: 8.9775 - val_age_output_loss: 8.2354 - val_age_output_mae: 8.2429 - val_gender_output_accuracy: 0.8790 - val_gender_output_loss: 0.2796 - val_loss: 8.5236
# Epoch 9/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 265s 891ms/step - age_output_loss: 8.3911 - age_output_mae: 8.3914 - gender_output_accuracy: 0.8755 - gender_output_loss: 0.3050 - loss: 8.6966 - val_age_output_loss: 8.0499 - val_age_output_mae: 8.0629 - val_gender_output_accuracy: 0.8870 - val_gender_output_loss: 0.2702 - val_loss: 8.3347
# Epoch 10/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 265s 891ms/step - age_output_loss: 8.3911 - age_output_mae: 8.3914 - gender_output_accuracy: 0.8755 - gender_output_loss: 0.3050 - loss: 8.6966 - val_age_output_loss: 8.0499 - val_age_output_mae: 8.0629 - val_gender_output_accuracy: 0.8870 - val_gender_output_loss: 0.2702 - val_loss: 8.3347
# Epoch 10/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 233s 784ms/step - age_output_loss: 8.1829 - age_output_mae: 8.1800 - gender_output_accuracy: 0.8804 - gender_output_loss: 0.2914 - loss: 8.4716 - val_age_output_loss: 7.8773 - val_age_output_mae: 7.8893 - val_gender_output_accuracy: 0.8868 - val_gender_output_loss: 0.2722 - val_loss: 8.1630
# Epoch 11/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 233s 784ms/step - age_output_loss: 8.1829 - age_output_mae: 8.1800 - gender_output_accuracy: 0.8804 - gender_output_loss: 0.2914 - loss: 8.4716 - val_age_output_loss: 7.8773 - val_age_output_mae: 7.8893 - val_gender_output_accuracy: 0.8868 - val_gender_output_loss: 0.2722 - val_loss: 8.1630
# Epoch 11/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 221s 745ms/step - age_output_loss: 7.9951 - age_output_mae: 7.9973 - gender_output_accuracy: 0.8819 - gender_output_loss: 0.2899 - loss: 8.2874 - val_age_output_loss: 7.9316 - val_age_output_mae: 7.9293 - val_gender_output_accuracy: 0.8849 - val_gender_output_loss: 0.2761 - val_loss: 8.2060
# Epoch 12/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 221s 745ms/step - age_output_loss: 7.9951 - age_output_mae: 7.9973 - gender_output_accuracy: 0.8819 - gender_output_loss: 0.2899 - loss: 8.2874 - val_age_output_loss: 7.9316 - val_age_output_mae: 7.9293 - val_gender_output_accuracy: 0.8849 - val_gender_output_loss: 0.2761 - val_loss: 8.2060
# Epoch 12/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 234s 788ms/step - age_output_loss: 7.8565 - age_output_mae: 7.8559 - gender_output_accuracy: 0.8914 - gender_output_loss: 0.2678 - loss: 8.1238 - val_age_output_loss: 7.6563 - val_age_output_mae: 7.6542 - val_gender_output_accuracy: 0.8899 - val_gender_output_loss: 0.2602 - val_loss: 7.9139
# Epoch 13/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 234s 788ms/step - age_output_loss: 7.8565 - age_output_mae: 7.8559 - gender_output_accuracy: 0.8914 - gender_output_loss: 0.2678 - loss: 8.1238 - val_age_output_loss: 7.6563 - val_age_output_mae: 7.6542 - val_gender_output_accuracy: 0.8899 - val_gender_output_loss: 0.2602 - val_loss: 7.9139
# Epoch 13/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - age_output_loss: 7.6735 - age_output_mae: 7.6764 - gender_output_accuracy: 0.8887 - gender_output_loss: 0.2769 - loss: 7.9520 - val_age_output_loss: 7.9348 - val_age_output_mae: 7.9305 - val_gender_output_accuracy: 0.8821 - val_gender_output_loss: 0.2817 - val_loss: 8.2116
# Epoch 14/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - age_output_loss: 7.6735 - age_output_mae: 7.6764 - gender_output_accuracy: 0.8887 - gender_output_loss: 0.2769 - loss: 7.9520 - val_age_output_loss: 7.9348 - val_age_output_mae: 7.9305 - val_gender_output_accuracy: 0.8821 - val_gender_output_loss: 0.2817 - val_loss: 8.2116
# Epoch 14/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 314s 1s/step - age_output_loss: 7.6056 - age_output_mae: 7.6006 - gender_output_accuracy: 0.8997 - gender_output_loss: 0.2485 - loss: 7.8494 - val_age_output_loss: 7.8570 - val_age_output_mae: 7.8676 - val_gender_output_accuracy: 0.8992 - val_gender_output_loss: 0.2489 - val_loss: 8.1176
# Epoch 15/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 314s 1s/step - age_output_loss: 7.6056 - age_output_mae: 7.6006 - gender_output_accuracy: 0.8997 - gender_output_loss: 0.2485 - loss: 7.8494 - val_age_output_loss: 7.8570 - val_age_output_mae: 7.8676 - val_gender_output_accuracy: 0.8992 - val_gender_output_loss: 0.2489 - val_loss: 8.1176
# Epoch 15/15
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 259s 872ms/step - age_output_loss: 7.4792 - age_output_mae: 7.4837 - gender_output_accuracy: 0.9021 - gender_output_loss: 0.2427 - loss: 7.7264 - val_age_output_loss: 7.7325 - val_age_output_mae: 7.7237 - val_gender_output_accuracy: 0.8965 - val_gender_output_loss: 0.2408 - val_loss: 7.9658
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 259s 872ms/step - age_output_loss: 7.4792 - age_output_mae: 7.4837 - gender_output_accuracy: 0.9021 - gender_output_loss: 0.2427 - loss: 7.7264 - val_age_output_loss: 7.7325 - val_age_output_mae: 7.7237 - val_gender_output_accuracy: 0.8965 - val_gender_output_loss: 0.2408 - val_loss: 7.9658
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved as age_gender_model.h5
